# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. *df.replace()* function

# %% [markdown]
# ### 1.1 Eamples

# %%
df_world = pd.read_csv('/content/drive/MyDrive/world_happiness_dataset.csv')
df_world.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %%
df_world = df_world.replace('Finland','Vinland')
df_world.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Vinland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %%
df_world = df_world.replace(['Vinland','Denmark','Norway'],'Scandinavia')
df_world.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1       Scandinavia  ...       0.153                      0.393
# 1             2       Scandinavia  ...       0.252                      0.410
# 2             3       Scandinavia  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %%
df_world['Score 1'] = (df_world['Score'] > 7.5)
df_world['Score 1'] = df_world['Score 1'].replace([True,False],[0,1])
df_world.head()
# Out:
#    Overall rank Country or region  ...  Perceptions of corruption  Score 1
# 0             1       Scandinavia  ...                      0.393        0
# 1             2       Scandinavia  ...                      0.410        0
# 2             3       Scandinavia  ...                      0.341        0
# 3             4           Iceland  ...                      0.118        1
# 4             5       Netherlands  ...                      0.298        1
#
# [5 rows x 10 columns]

# %%
df_world.head()
# Out:
#    Overall rank Country or region  ...  Perceptions of corruption  Score 1
# 0             1       Scandinavia  ...                      0.393        0
# 1             2       Scandinavia  ...                      0.410        0
# 2             3       Scandinavia  ...                      0.341        0
# 3             4           Iceland  ...                      0.118        1
# 4             5       Netherlands  ...                      0.298        1
#
# [5 rows x 10 columns]

# %% [markdown]
# ### 1.2 Cases where the replace function lacks
# - **When multiple values need to be replaced**. In this case, the *replace* function creates tedious and inefficient code.
# - **When a continuous range of values need to be replaced**
# - **When values fitting a certain condition need to be replaced**. Since the specific values would be unknown in this case, the *replace* function would not be too useful.

# %% [markdown]
# ## 2. *np.where()* function

# %%
df_world = pd.read_csv('/content/drive/MyDrive/world_happiness_dataset.csv')
df_world.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %%
df_world['Score 1'] = np.where(df_world['Score'] > 7.5,1,0)
df_world.head()
# Out:
#    Overall rank Country or region  ...  Perceptions of corruption  Score 1
# 0             1           Finland  ...                      0.393        1
# 1             2           Denmark  ...                      0.410        1
# 2             3            Norway  ...                      0.341        1
# 3             4           Iceland  ...                      0.118        0
# 4             5       Netherlands  ...                      0.298        0
#
# [5 rows x 10 columns]

# %% [markdown]
# ## 3. *df.between()* function

# %%
df_world = pd.read_csv('/content/drive/MyDrive/world_happiness_dataset.csv')
df_world.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %%
df_world['Score 1'] = np.where(df_world['Score'].between(7.5,7.6),1,0)
df_world.head()
# Out:
#    Overall rank Country or region  ...  Perceptions of corruption  Score 1
# 0             1           Finland  ...                      0.393        0
# 1             2           Denmark  ...                      0.410        1
# 2             3            Norway  ...                      0.341        1
# 3             4           Iceland  ...                      0.118        0
# 4             5       Netherlands  ...                      0.298        0
#
# [5 rows x 10 columns]

# %% [markdown]
# ## 4. *df.mask()* function

# %%
df_world = pd.read_csv('/content/drive/MyDrive/world_happiness_dataset.csv')
df_world.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %%
df_world['Score 1'] = df_world['Score'].mask(df_world['Score'] < 7.5,0)
df_world.head()
# Out:
#    Overall rank Country or region  ...  Perceptions of corruption  Score 1
# 0             1           Finland  ...                      0.393    7.769
# 1             2           Denmark  ...                      0.410    7.600
# 2             3            Norway  ...                      0.341    7.554
# 3             4           Iceland  ...                      0.118    0.000
# 4             5       Netherlands  ...                      0.298    0.000
#
# [5 rows x 10 columns]

# %%
df_world['Score 1'] = df_world['Score 1'].mask(df_world['Score 1'] > 7.5,1)
df_world.head()
# Out:
#    Overall rank Country or region  ...  Perceptions of corruption  Score 1
# 0             1           Finland  ...                      0.393      1.0
# 1             2           Denmark  ...                      0.410      1.0
# 2             3            Norway  ...                      0.341      1.0
# 3             4           Iceland  ...                      0.118      0.0
# 4             5       Netherlands  ...                      0.298      0.0
#
# [5 rows x 10 columns]

# %% [markdown]
# ## 5. Replace, Mask, Where and Between functions - More examples
#
# https://stackoverflow.com/questions/46168450/replace-a-specific-range-of-values-in-a-pandas-dataframe

# %%
df = pd.DataFrame({'A': [0, 1, 2, 3, 4],
                   'B': [5, 6, 7, 8, 9],
                   'C': ['a', 'b', 'c', 'd', 'e']})

df
# Out:
#    A  B  C
# 0  0  5  a
# 1  1  6  b
# 2  2  7  c
# 3  3  8  d
# 4  4  9  e

# %%
df.replace({0: 10, 1: 100})
# Out:
#      A  B  C
# 0   10  5  a
# 1  100  6  b
# 2    2  7  c
# 3    3  8  d
# 4    4  9  e

# %%
df.replace({'A': 0, 'B': 5}, 100)
# Out:
#      A    B  C
# 0  100  100  a
# 1    1    6  b
# 2    2    7  c
# 3    3    8  d
# 4    4    9  e

# %%
df.replace({'A': {0: 100, 4: 400}})
# Out:
#      A  B  C
# 0  100  5  a
# 1    1  6  b
# 2    2  7  c
# 3    3  8  d
# 4  400  9  e

# %%
new_dict = {'A':[1,2,3,4,5,6,7,8,9],'B':[11,12,13,14,15,16,17,18,19]}
df_dict = pd.DataFrame(new_dict)
df_dict
# Out:
#    A   B
# 0  1  11
# 1  2  12
# 2  3  13
# 3  4  14
# 4  5  15
# 5  6  16
# 6  7  17
# 7  8  18
# 8  9  19

# %%
df_dict['A'].mask(df_dict['A']>4,100)
# Out:
# 0      1
# 1      2
# 2      3
# 3      4
# 4    100
# 5    100
# 6    100
# 7    100
# 8    100
# Name: A, dtype: int64

# %%
np.where(df_dict['A']>4,100,df_dict['A'])
# Out:
# array([  1,   2,   3,   4, 100, 100, 100, 100, 100])

# %%
np.where(df_dict['A'].between(3,6),100,df_dict['A'])
# Out:
# array([  1,   2, 100, 100, 100, 100,   7,   8,   9])
